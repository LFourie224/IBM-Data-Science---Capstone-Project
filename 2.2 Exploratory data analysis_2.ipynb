# %% [markdown]
# # Further analysis on ML formatted data

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Import dataset
# ## Same dataset used for Exploratory Analysis

# %%
AccidentData5 = pd.read_csv('E:\Training Development\Coursera\IBM Data Science\Course 9 - Capstone Project\Capstone Project Data\AccidentData_4.csv')

# %%
AccidentData5.head()
# Out:
#    OBJECTID  SEVERITYCODE  JUNCTIONTYPE  WEATHER  ROADCOND  LIGHTCOND  \
# 0         1             2             2        1         9          6
# 1         2             1             3        2         9          3
# 2         3             1             3        1         1          6
# 3         4             1             3        3         1          6
# 4         5             2             2        2         9          6
#
#    Day of week  Month of Year
# 0            2              3
# 1            2             12
# 2            3             11
# 3            4              3
# 4            2              1

# %%
len(AccidentData5.index)
# Out:
# 189337

# %% [markdown]
# # Analyse impact of weather, road condition, light condition, day of week, time of year and juntion type on severity of the accident

# %%
AccidentData5.hist(column='WEATHER', bins=22)
# Out:
# array([[<AxesSubplot:title={'center':'WEATHER'}>]], dtype=object)

# %%
AccidentData5.hist(column='LIGHTCOND', bins=22)
# Out:
# array([[<AxesSubplot:title={'center':'LIGHTCOND'}>]], dtype=object)

# %%
AccidentData5.hist(column='ROADCOND', bins=22)
# Out:
# array([[<AxesSubplot:title={'center':'ROADCOND'}>]], dtype=object)

# %%
AccidentData5.hist(column='JUNCTIONTYPE', bins=22)
# Out:
# array([[<AxesSubplot:title={'center':'JUNCTIONTYPE'}>]], dtype=object)
